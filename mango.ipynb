# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithap99/ripefruitidentification/blob/master/mango.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
get_ipython().magic('matplotlib inline')
import cv2
import matplotlib
from matplotlib import colors
from matplotlib import pyplot as plt
import numpy as np

# %%
# !wget "https://5.imimg.com/data5/BD/EK/HP/SELLER-7051866/mango-fruit-500x500.jpg" -O dt.jpg
image = cv2.imread('./dt.jpg')
plt.imshow(image)
plt.show()
#imshow reads color in BGR(blue,green,red)
image.shape
# Out:
# --2020-04-16 12:33:01--  https://5.imimg.com/data5/BD/EK/HP/SELLER-7051866/mango-fruit-500x500.jpg
# Resolving 5.imimg.com (5.imimg.com)... 13.224.13.20, 13.224.13.88, 13.224.13.125, ...
# Connecting to 5.imimg.com (5.imimg.com)|13.224.13.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33615 (33K) [image/jpeg]
# Saving to: ‘dt.jpg’
#
# dt.jpg              100%[===================>]  32.83K   148KB/s    in 0.2s
#
# 2020-04-16 12:33:02 (148 KB/s) - ‘dt.jpg’ saved [33615/33615]
# (500, 500, 3)

# %%
# Convert from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Resize to a third of the size
image = cv2.resize(image, None, fx=1/3, fy=1/3)
plt.figure(figsize=(15, 15))
    
    # Show image, with nearest neighbour interpolation
plt.imshow(image, interpolation='nearest')

# %%
row,col,plane = image.shape
temp = np.zeros((row,col,plane),np.uint8)
temp[:,:,0] = image[:,:,0]

# displaying the Red plane image
plt.imshow(temp)
plt.show()

# again take a zero matrix of image matrix shape
temp = np.zeros((row,col,plane),np.uint8)
temp[:,:,1] = image[:,:,1]

# displaying the Green plane image
plt.imshow(temp)
plt.show()


# again take a zero matrix of image matrix shape
temp = np.zeros((row,col,plane),np.uint8)
temp[:,:,2] = image[:,:,2]

# displaying the Blue plane image
plt.imshow(temp)
plt.show()

# %%
# Convert from RGB to HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)
images = []
for i in [0, 1, 2]:
    colour = hsv.copy()
    if i != 0: colour[:,:,0] = 0
    if i != 1: colour[:,:,1] = 255
    if i != 2: colour[:,:,2] = 255
    images.append(colour)
    
hsv_stack = np.vstack(images)
rgb_stack = cv2.cvtColor(hsv_stack, cv2.COLOR_HSV2RGB)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(rgb_stack, interpolation='nearest')

# %%
# Blur image slightly
image_blur = cv2.GaussianBlur(image, (7, 7), 0)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(image_blur, interpolation='nearest')
