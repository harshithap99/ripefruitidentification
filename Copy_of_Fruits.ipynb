# %% [markdown]
# <a href="https://colab.research.google.com/github/harshithap99/ripefruitidentification/blob/master/Copy_of_Fruits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
get_ipython().magic('matplotlib inline')
import cv2
import matplotlib
from matplotlib import colors
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# FRUIT 1 - *STRAWBERRY*

# %%
# !wget "https://media.istockphoto.com/photos/tomato-isolated-on-white-background-picture-id466175630?k=6&m=466175630&s=612x612&w=0&h=fu_mQBjGJZIliOWwCR0Vf2myRvKWyQDsymxEIi8tZ38=" -O dt.jpg
image = cv2.imread('./dt.jpg')
plt.imshow(image)
plt.show()
#imshow reads color in BGR(blue,green,red)
image.shape
# Out:
# --2020-05-01 09:00:26--  https://media.istockphoto.com/photos/tomato-isolated-on-white-background-picture-id466175630?k=6&m=466175630&s=612x612&w=0&h=fu_mQBjGJZIliOWwCR0Vf2myRvKWyQDsymxEIi8tZ38=
# Resolving media.istockphoto.com (media.istockphoto.com)... 13.226.185.101, 13.226.185.82, 13.226.185.46, ...
# Connecting to media.istockphoto.com (media.istockphoto.com)|13.226.185.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35320 (34K) [image/jpeg]
# Saving to: ‘dt.jpg’
#
# dt.jpg              100%[===================>]  34.49K  --.-KB/s    in 0.02s
#
# 2020-05-01 09:00:26 (1.42 MB/s) - ‘dt.jpg’ saved [35320/35320]
# (612, 612, 3)

# %%
# Convert from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Resize to a third of the size
image = cv2.resize(image, None, fx=1/3, fy=1/3)
plt.figure(figsize=(15, 15))
    
    # Show image, with nearest neighbour interpolation
plt.imshow(image, interpolation='nearest')

# %%
def display_RGB(image):
    row,col,plane = image.shape
    temp = np.zeros((row,col,plane),np.uint8)
    temp[:,:,0] = image[:,:,0]

  # displaying the Red plane image
    plt.imshow(temp)
    plt.show()

  # again take a zero matrix of image matrix shape
    temp = np.zeros((row,col,plane),np.uint8)
    temp[:,:,1] = image[:,:,1]

  # displaying the Green plane image
    plt.imshow(temp)
    plt.show()


  # again take a zero matrix of image matrix shape
    temp = np.zeros((row,col,plane),np.uint8)
    temp[:,:,2] = image[:,:,2]

  # displaying the Blue plane image
    plt.imshow(temp)
    plt.show()

# %%
display_RGB(image)

# %%
# Convert from RGB to HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)
images = []
for i in [0, 1, 2]:
    colour = hsv.copy()
    if i != 0: colour[:,:,0] = 0
    if i != 1: colour[:,:,1] = 255
    if i != 2: colour[:,:,2] = 255
    images.append(colour)
hsv_stack = np.vstack(images)
rgb_stack = cv2.cvtColor(hsv_stack, cv2.COLOR_HSV2RGB)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(rgb_stack, interpolation='nearest')

# %%
# Blur image slightly
image_blur = cv2.GaussianBlur(image, (7, 7), 0)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(image_blur, interpolation='nearest')

# %%
image_blur_hsv = cv2.cvtColor(image_blur, cv2.COLOR_RGB2HSV)
# 170-180 hue
min_red2 = np.array([170, 100, 60])
max_red2 = np.array([180, 256, 256])
image_red2 = cv2.inRange(image_blur_hsv, min_red2, max_red2)
plt.figure(figsize=(10, 10))
plt.imshow(image_red2,cmap='gray')

# %%
# to get elliptical shaped kernels we use the function cv2.getStructuringElement()
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))

#to close small holes
image_red_closed = cv2.morphologyEx(image_red2, cv2.MORPH_CLOSE, kernel)
plt.figure(figsize=(10, 10))
plt.imshow(image_red_closed,cmap='gray')

# %% [markdown]
# FRUIT 2 - *MANGO*

# %%
# !wget "https://5.imimg.com/data5/YD/PM/MY-40752733/fresh-mango-500x500.jpg" -O dt.jpg
image = cv2.imread('./dt.jpg')
plt.imshow(image)
plt.show()
#imshow reads color in BGR(blue,green,red)
image.shape
# Out:
# --2020-04-28 16:16:50--  https://5.imimg.com/data5/YD/PM/MY-40752733/fresh-mango-500x500.jpg
# Resolving 5.imimg.com (5.imimg.com)... 13.35.7.62, 13.35.7.20, 13.35.7.7, ...
# Connecting to 5.imimg.com (5.imimg.com)|13.35.7.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25320 (25K) [image/jpg]
# Saving to: ‘dt.jpg’
#
# dt.jpg              100%[===================>]  24.73K  --.-KB/s    in 0.001s
#
# 2020-04-28 16:16:50 (25.0 MB/s) - ‘dt.jpg’ saved [25320/25320]
# (500, 500, 3)

# %%
# Convert from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Resize to a third of the size
image = cv2.resize(image, None, fx=1/3, fy=1/3)
plt.figure(figsize=(15, 15))
    
    # Show image, with nearest neighbour interpolation
plt.imshow(image, interpolation='nearest')

# %%
display_RGB(image)

# %%
# Convert from RGB to HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)
images = []
for i in [0, 1, 2]:
    colour = hsv.copy()
    if i != 0: colour[:,:,0] = 0
    if i != 1: colour[:,:,1] = 255
    if i != 2: colour[:,:,2] = 255
    images.append(colour)
hsv_stack = np.vstack(images)
rgb_stack = cv2.cvtColor(hsv_stack, cv2.COLOR_HSV2RGB)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(rgb_stack, interpolation='nearest')

# %%
# Blur image slightly
image_blur = cv2.GaussianBlur(image, (7, 7), 0)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(image_blur, interpolation='nearest')

# %%
image_blur_hsv = cv2.cvtColor(image_blur, cv2.COLOR_RGB2HSV)
yellow_lower = np.array([20, 100, 100])
yellow_upper = np.array([30, 255, 255])
mask_yellow = cv2.inRange(image_blur_hsv, yellow_lower, yellow_upper)
plt.figure(figsize=(10, 10))
plt.imshow(mask_yellow,cmap='gray')

# %%
# to get elliptical shaped kernels we use the function cv2.getStructuringElement()
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))

#closes small holes
image_yellow_closed = cv2.morphologyEx(mask_yellow, cv2.MORPH_CLOSE, kernel)
plt.figure(figsize=(10, 10))
plt.imshow(image_yellow_closed,cmap='gray')

# %% [markdown]
# FRUIT 3 - **

# %%
# !wget "https://www.kitchenbutterfly.com/wp-content/uploads/2019/07/wcf2.jpg" -O dt.jpg
image = cv2.imread('./dt.jpg')
plt.imshow(image)
plt.show()
#imshow reads color in BGR(blue,green,red)
image.shape
# Out:
# --2020-05-01 08:55:16--  https://www.kitchenbutterfly.com/wp-content/uploads/2019/07/wcf2.jpg
# Resolving www.kitchenbutterfly.com (www.kitchenbutterfly.com)... 162.144.90.17
# Connecting to www.kitchenbutterfly.com (www.kitchenbutterfly.com)|162.144.90.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2041370 (1.9M) [image/jpeg]
# Saving to: ‘dt.jpg’
#
# dt.jpg              100%[===================>]   1.95M  2.15MB/s    in 0.9s
#
# 2020-05-01 08:55:18 (2.15 MB/s) - ‘dt.jpg’ saved [2041370/2041370]
# (1536, 2048, 3)

# %%
# Convert from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Resize to a third of the size
image = cv2.resize(image, None, fx=1/3, fy=1/3)
plt.figure(figsize=(15, 15))
    
    # Show image, with nearest neighbour interpolation
plt.imshow(image, interpolation='nearest')

# %%
def display_RGB(image):
    row,col,plane = image.shape
    temp = np.zeros((row,col,plane),np.uint8)
    temp[:,:,0] = image[:,:,0]

  # displaying the Red plane image
    plt.imshow(temp)
    plt.show()

  # again take a zero matrix of image matrix shape
    temp = np.zeros((row,col,plane),np.uint8)
    temp[:,:,1] = image[:,:,1]

  # displaying the Green plane image
    plt.imshow(temp)
    plt.show()


  # again take a zero matrix of image matrix shape
    temp = np.zeros((row,col,plane),np.uint8)
    temp[:,:,2] = image[:,:,2]

  # displaying the Blue plane image
    plt.imshow(temp)
    plt.show()

# %%
display_RGB(image)

# %%
# Convert from RGB to HSV
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)
images = []
for i in [0, 1, 2]:
    colour = hsv.copy()
    if i != 0: colour[:,:,0] = 0
    if i != 1: colour[:,:,1] = 255
    if i != 2: colour[:,:,2] = 255
    images.append(colour)
hsv_stack = np.vstack(images)
rgb_stack = cv2.cvtColor(hsv_stack, cv2.COLOR_HSV2RGB)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(rgb_stack, interpolation='nearest')

# %%
# Blur image slightly
image_blur = cv2.GaussianBlur(image, (7, 7), 0)
plt.figure(figsize=(15, 15))
# Show image, with nearest neighbour interpolation
plt.imshow(image_blur, interpolation='nearest')

# %%
image_blur_hsv = cv2.cvtColor(image_blur, cv2.COLOR_RGB2HSV)
orange_lower = np.array([10, 100, 100])
orange_upper = np.array([20, 255, 255])
mask_orange = cv2.inRange(image_blur_hsv, orange_lower, orange_upper)
plt.figure(figsize=(10, 10))
plt.imshow(mask_orange,cmap='gray')

# %%
# to get elliptical shaped kernels we use the function cv2.getStructuringElement()
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))

#closes small holes
image_orange_closed = cv2.morphologyEx(mask_orange, cv2.MORPH_CLOSE, kernel)
plt.figure(figsize=(10, 10))
plt.imshow(image_orange_closed,cmap='gray')
